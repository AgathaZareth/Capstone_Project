# %% [markdown]
# # Introduction

# %% [markdown]
# This notebook takes DFs from INSERT and INSERT and creates a new df to be modeled with. Part of this process cleans date, counts wins, loses, gets win percentage for each team for each year. creates new features of teams aggrigated stats. Final DF has TEAM, YEAR, TEAM STATS, WIN PERCENTAGE

# %% [markdown]
# # Imports

# %%
import pandas as pd

# %% [markdown]
# # Load Needed DF's

# %% [markdown]
# ## `MLB_5_seasons`
# The last 5 seasons for MLB, starting at 2022, skipping 2020 due to covid, ending at 2017.

# %%
# load
MLB_5_seasons = pd.read_pickle("../pickled_tables/MLB_5_seasons_df.pkl")

# view
MLB_5_seasons
# Out:
#      Team  Games Played  At Bats  Runs  Hits  Doubles  Triples  Home Runs  \
# 0     NYM             2        2     1     1        0        0          1
# 1     ATL             1        4     0     3        2        0          0
# 2     LAD             4       13     6     6        2        0          1
# 3     TOR             8        9     0     6        0        0          0
# 4     NYY            47      128    28    39        9        0         15
# ...   ...           ...      ...   ...   ...      ...      ...        ...
# 5949  BAL             9        1     0     0        0        0          0
# 5950  CWS            22        0     0     0        0        0          0
# 5951   KC            14        0     0     0        0        0          0
# 5952  MIA            53        0     0     0        0        0          0
# 5953  SEA            45        0     0     0        0        0          0
#
#       Runs Batted In  Walks  Strikeouts  Stolen Bases  Caught Stealing  \
# 0                  3      0           0             0                0
# 1                  3      0           0             0                0
# 2                  3      2           7             0                0
# 3                  3      1           1             0                1
# 4                 37     19          35             0                0
# ...              ...    ...         ...           ...              ...
# 5949               0      0           0             0                0
# 5950               0      0           0             0                0
# 5951               0      0           0             0                0
# 5952               0      0           0             0                0
# 5953               0      0           0             0                0
#
#       Batting Average  On-Base Percentage  Slugging Percentage  \
# 0               0.500               0.500                2.000
# 1               0.750               0.750                1.250
# 2               0.462               0.563                0.846
# 3               0.667               0.700                0.667
# 4               0.305               0.412                0.727
# ...               ...                 ...                  ...
# 5949            0.000               0.000                0.000
# 5950            0.000               0.000                0.000
# 5951            0.000               0.000                0.000
# 5952            0.000               0.000                0.000
# 5953            0.000               0.000                0.000
#
#       On-Base Plus Slugging  Year       Player Name Position
# 0                     2.500  2022      Khalil  Lee        CF
# 1                     2.000  2022  Chadwick  Tromp         C
# 2                     1.409  2022    James  Outman        LF
# 3                     1.367  2022      Otto  Lopez        SS
# 4                     1.139  2022  Matt  Carpenter        DH
# ...                     ...   ...               ...      ...
# 5949                  0.000  2017    Gabriel  Ynoa         P
# 5950                  0.000  2017    Michael  Ynoa         P
# 5951                  0.000  2017     Chris  Young         P
# 5952                  0.000  2017    Brad  Ziegler         P
# 5953                  0.000  2017       Tony  Zych         P
#
# [5954 rows x 20 columns]

# %% [markdown]
# ## Load df's with regular season games

# %%
# load
games_2017 = pd.read_pickle("../pickled_tables/2017_df.pkl")
games_2018 = pd.read_pickle("../pickled_tables/2018_df.pkl")
games_2019 = pd.read_pickle("../pickled_tables/2019_df.pkl")
games_2021 = pd.read_pickle("../pickled_tables/2021_df.pkl")
games_2022 = pd.read_pickle("../pickled_tables/2022_df.pkl")

# view 1
games_2017
# Out:
#          Day Month Date Away Home  Win W Score Lose L Score
# 0     Sunday   Apr    2  NYY   TB   TB       7  NYY       3
# 1     Sunday   Apr    2   SF   AZ   AZ       6   SF       5
# 2     Sunday   Apr    2  CHC  STL  STL       4  CHC       3
# 3     Monday   Apr    3  MIA  WSH  WSH       4  MIA       2
# 4     Monday   Apr    3  ATL  NYM  NYM       6  ATL       0
# ...      ...   ...  ...  ...  ...  ...     ...  ...     ...
# 2425  Sunday   Oct    1  CWS  CLE  CLE       3  CWS       1
# 2426  Sunday   Oct    1  ATL  MIA  ATL       8  MIA       5
# 2427  Sunday   Oct    1   AZ   KC   AZ      14   KC       2
# 2428  Sunday   Oct    1  MIL  STL  MIL       6  STL       1
# 2429  Sunday   Oct    1  CIN  CHC  CIN       3  CHC       1
#
# [2430 rows x 9 columns]

# %% [markdown]
# # Functions
# To streamline the workflow I put most of the df transformations into functions

# %% [markdown]
# ## `make_year_string`
# This function is simply to make is easier to input year and ensure a valid year is input.

# %%
def make_year_string(year):
    if type(year) == int:
        year = str(year)
        
    if year not in ['2022', '2021', '2019', '2018', '2017']:
        print("ValueError: Enter a valid year ['2022', '2021', '2019', '2018', '2017']")
    else:
        return year

# %% [markdown]
# ### Examples

# %%
make_year_string(2020)
# Out:
# ValueError: Enter a valid year ['2022', '2021', '2019', '2018', '2017']

# %%
make_year_string(2022)
# Out:
# '2022'

# %% [markdown]
# ## `get_team_to_agg`
# ("Get team to aggrigate")
#
# This function selects a team and a year and filters out the players with less than 5 at bats.

# %%
def get_team_to_agg(team, year):
    
    # ensure year is string
    year = make_year_string(year)
    
    # ensure year is valid
    if year in ['2022', '2021', '2019', '2018', '2017']:
        entire_team = MLB_5_seasons[MLB_5_seasons['Year']==year][MLB_5_seasons[MLB_5_seasons['Year']==year]['Team'] == team]

        return entire_team[entire_team['At Bats'] > 5]

# %% [markdown]
# ### Examples

# %%
get_team_to_agg('SF', 2020)
# Out:
# ValueError: Enter a valid year ['2022', '2021', '2019', '2018', '2017']

# %%
get_team_to_agg('SF', 2022)
# Out:
#     Team  Games Played  At Bats  Runs  Hits  Doubles  Triples  Home Runs  \
# 30    SF           134      380    57   104       19        3         23
# 68    SF             3        8     1     3        0        0          0
# 78    SF            36       98    14    26        6        1          4
# 111   SF            52      156    21    36        6        1          9
# 118   SF           125      277    49    73       15        2          7
# 134   SF            89      266    31    65       13        0         14
# 142   SF           115      318    46    79       16        1         12
# 210   SF           140      488    71   127       22        2         14
# 229   SF           151      525    72   120       28        1         19
# 262   SF           148      485    73   104       31        2         17
# 287   SF            16       36     5     6        2        0          3
# 288   SF            98      311    31    79       17        2          4
# 302   SF            78      254    25    54        9        1          8
# 313   SF            66      162    14    42        7        0          3
# 318   SF            31       73     9    17        5        0          1
# 323   SF            77      217    29    45        7        1          8
# 330   SF            97      261    34    56        6        0         11
# 346   SF           118      407    50    94       15        2          9
# 396   SF            60      180    17    43       14        0          2
# 543   SF            22       52     7     7        3        0          1
# 564   SF             5       15     1     3        0        0          0
# 571   SF            25       76     9    12        8        0          1
# 583   SF             7       18     3     2        0        0          1
# 603   SF             3        8     0     1        0        0          0
# 619   SF            16       39     4     5        1        0          0
# 653   SF             9       20     4     2        0        0          0
# 654   SF            11       18     1     2        0        0          0
#
#      Runs Batted In  Walks  Strikeouts  Stolen Bases  Caught Stealing  \
# 30               70     42         100             3                2
# 68                0      1           0             0                0
# 78               12     10          29             1                1
# 111              24     18          58             0                1
# 118              34     40          89            12                1
# 134              42     27          83             0                0
# 142              35     39         122             1                1
# 210              62     33          89            21                6
# 229              71     59         103             0                0
# 262              57     61         141             5                1
# 287               4      2          14             1                0
# 288              36     30          75            10                2
# 302              23     37          81             1                0
# 313              21     10          38             0                0
# 318               8      9          17             0                0
# 323              26     26          51             1                0
# 330              25     26         112             2                1
# 346              52     39          98             1                1
# 396              14     11          30             0                0
# 543               3      9           8             0                0
# 564               0      1           5             0                0
# 571               8      1          16             0                0
# 583               6      2           3             0                0
# 603               0      2           3             0                0
# 619               4      5          12             0                0
# 653               0      2           6             0                0
# 654               2      1           7             0                0
#
#      Batting Average  On-Base Percentage  Slugging Percentage  \
# 30             0.274               0.353                0.521
# 68             0.375               0.444                0.375
# 78             0.265               0.342                0.469
# 111            0.231               0.331                0.455
# 118            0.264               0.366                0.408
# 134            0.244               0.315                0.451
# 142            0.248               0.340                0.418
# 210            0.260               0.322                0.400
# 229            0.229               0.316                0.394
# 262            0.214               0.305                0.392
# 287            0.167               0.211                0.472
# 288            0.254               0.323                0.360
# 302            0.213               0.326                0.350
# 313            0.259               0.313                0.358
# 318            0.233               0.325                0.342
# 323            0.207               0.305                0.359
# 330            0.215               0.296                0.364
# 346            0.231               0.308                0.344
# 396            0.239               0.282                0.350
# 543            0.135               0.274                0.250
# 564            0.200               0.294                0.200
# 571            0.158               0.179                0.303
# 583            0.111               0.182                0.278
# 603            0.125               0.300                0.125
# 619            0.128               0.239                0.154
# 653            0.100               0.182                0.100
# 654            0.111               0.158                0.111
#
#      On-Base Plus Slugging  Year         Player Name Position
# 30                   0.874  2022      Joc  Pederson        LF
# 68                   0.819  2022       Austin  Dean        LF
# 78                   0.811  2022      Jason  Vosler        3B
# 111                  0.786  2022      David  Villar        3B
# 118                  0.774  2022     Austin  Slater        CF
# 134                  0.766  2022     Evan  Longoria        3B
# 142                  0.758  2022        J.D.  Davis        3B
# 210                  0.722  2022    Thairo  Estrada        2B
# 229                  0.710  2022     Wilmer  Flores        2B
# 262                  0.697  2022  Mike  Yastrzemski        RF
# 287                  0.683  2022     Lewis  Brinson        CF
# 288                  0.683  2022     Luis  Gonzalez        RF
# 302                  0.676  2022      Brandon  Belt        1B
# 313                  0.671  2022      Austin  Wynns         C
# 318                  0.667  2022   Yermin  Mercedes        DH
# 323                  0.664  2022  LaMonte  Wade  Jr.       RF
# 330                  0.660  2022         Joey  Bart         C
# 346                  0.652  2022  Brandon  Crawford        SS
# 396                  0.632  2022   Tommy  La Stella        DH
# 543                  0.524  2022    Willie  Calhoun        DH
# 564                  0.494  2022     Dixon  Machado        SS
# 571                  0.482  2022    Donovan  Walton        2B
# 583                  0.460  2022      Ford  Proctor        2B
# 603                  0.425  2022      Jason  Krizan        LF
# 619                  0.393  2022      Andrew  Knapp         C
# 653                  0.282  2022      Heliot  Ramos        RF
# 654                  0.269  2022     Bryce  Johnson        CF

# %% [markdown]
# ## `extra_stats`
# Create stats for teams by year. Use `get_team_to_agg` to select a team by year and create a dataframe with team stats for that season.

# %%
def extra_stats(team, year):
    
    # ensure year is string
    year = make_year_string(year)
    
    # ensure year is valid
    if year in ['2022', '2021', '2019', '2018', '2017']:
        try:
            
            # cumulative totals - sum all players with more than 10 at bats
            # avoid stats that are combined (formulas, ex avg, obp, slg)
            g_sum = get_team_to_agg(team, year)['Games Played'].sum()
            ab_sum = get_team_to_agg(team, year)['At Bats'].sum()
            runs_sum = get_team_to_agg(team, year)['Runs'].sum()
            hits_sum = get_team_to_agg(team, year)['Hits'].sum()
            b2_sum = get_team_to_agg(team, year)['Doubles'].sum()
            b3_sum = get_team_to_agg(team, year)['Triples'].sum()
            hr_sum = get_team_to_agg(team, year)['Home Runs'].sum()
            rbi_sum = get_team_to_agg(team, year)['Runs Batted In'].sum()
            walks_sum = get_team_to_agg(team, year)['Walks'].sum()
            so_sum = get_team_to_agg(team, year)['Strikeouts'].sum()
            stolen_sum = get_team_to_agg(team, year)['Stolen Bases'].sum()
            cs_sum = get_team_to_agg(team, year)['Caught Stealing'].sum()
            
            
            # averages - average of players with more than 5 At Bats
            g_mean = get_team_to_agg(team, year)['Games Played'].mean()
            ab_mean = get_team_to_agg(team, year)['At Bats'].mean()
            runs_mean = get_team_to_agg(team, year)['Runs'].mean()
            hits_mean = get_team_to_agg(team, year)['Hits'].mean()
            b2_mean = get_team_to_agg(team, year)['Doubles'].mean()
            b3_mean = get_team_to_agg(team, year)['Triples'].mean()
            hr_mean = get_team_to_agg(team, year)['Home Runs'].mean()
            rbi_mean = get_team_to_agg(team, year)['Runs Batted In'].mean()
            walks_mean = get_team_to_agg(team, year)['Walks'].mean()
            so_mean = get_team_to_agg(team, year)['Strikeouts'].mean()
            stolen_mean = get_team_to_agg(team, year)['Stolen Bases'].mean()
            cs_mean = get_team_to_agg(team, year)['Caught Stealing'].mean()

            
            convert = [team, 
                       year, 
                       g_sum,
                       ab_sum,
                       runs_sum,
                       hits_sum,
                       b2_sum, 
                       b3_sum, 
                       hr_sum,
                       rbi_sum,
                       walks_sum,
                       so_sum,
                       stolen_sum,
                       cs_sum, 
                       g_mean, 
                       ab_mean, 
                       runs_mean, 
                       hits_mean, 
                       b2_mean, 
                       b3_mean, 
                       hr_mean, 
                       rbi_mean, 
                       walks_mean, 
                       so_mean, 
                       stolen_mean, 
                       cs_mean]

            cols = ['Team', 
                    'Year', 
                    'Games Played Sum',
                    'At Bats Sum', 
                    'Runs Sum',
                    'Hits Sum',
                    'Doubles Sum',
                    'Triples Sum',
                    'Home Runs Sum',
                    'Runs Batted In Sum',
                    'Walks Sum',
                    'Strikeouts Sum',
                    'Stolen Bases Sum',
                    'Caught Stealing Sum',
                    'Mean Games Played',
                    'Mean At Bats',
                    'Mean Runs',
                    'Mean Hits',
                    'Mean Doubles',
                    'Mean Triples',
                    'Mean Home Runs',
                    'Mean Runs Batted In',
                    'Mean Walks',
                    'Mean Strikeouts',
                    'Mean Stolen Bases',
                    'Mean Caught Stealing']
            
            df = pd.DataFrame(convert).T
            df.columns = cols
            
            return df
        
        except ValueError:
            pass

# %% [markdown]
# ### Examples

# %%
extra_stats('SF', 2020)
# Out:
# ValueError: Enter a valid year ['2022', '2021', '2019', '2018', '2017']

# %%
extra_stats('SF', 2022)
# Out:
#   Team  Year Games Played Sum At Bats Sum Runs Sum Hits Sum Doubles Sum  \
# 0   SF  2022             1732        5148      678     1207         250
#
#   Triples Sum Home Runs Sum Runs Batted In Sum  ... Mean Runs Mean Hits  \
# 0          19           171                639  ...   25.1111   44.7037
#
#   Mean Doubles Mean Triples Mean Home Runs Mean Runs Batted In Mean Walks  \
# 0      9.25926     0.703704        6.33333             23.6667    20.1111
#
#   Mean Strikeouts Mean Stolen Bases Mean Caught Stealing
# 0         51.4815           2.18519              0.62963
#
# [1 rows x 26 columns]

# %% [markdown]
# ## `clean_dates`
# Takes regular season games df and converts game day info to pandas date time format.

# %%
def clean_dates(year):
    # ensure year is string
    year = make_year_string(year)
    
    # ensure year is valid
    if year in ['2022', '2021', '2019', '2018', '2017']:
        if year == '2017':
            df = games_2017
        
        elif year == '2018':
            df = games_2018

        elif year == '2019':
            df = games_2019

        elif year == '2021':
            df = games_2021

        else: 
            df = games_2022


        # --- add a pandas datetime column ---
        new_df = df.copy()
        # empty list will be new column
        new_dates = []

        for index, row in df.iterrows():
            new_date = year + "-" + new_df['Month'][index] + "-" + new_df['Date'][index]
            new_dates.append(new_date)

        # convert to pd.to_datetime and overwrite current 'Date' column
        new_df['Date'] = pd.to_datetime(new_dates)

        # drop 'Month' and 'Day' columns
        new_df.drop(['Month', 'Day'], axis=1, inplace=True)


        return new_df

# %% [markdown]
# ### Examples

# %%
clean_dates(2020)
# Out:
# ValueError: Enter a valid year ['2022', '2021', '2019', '2018', '2017']

# %%
clean_dates(2022)
# Out:
#            Date Away Home  Win W Score Lose L Score
# 0    2022-04-07  MIL  CHC  CHC       5  MIL       4
# 1    2022-04-07  CLE   KC   KC       3  CLE       1
# 2    2022-04-07  PIT  STL  STL       9  PIT       0
# 3    2022-04-07  NYM  WSH  NYM       5  WSH       1
# 4    2022-04-07  CIN  ATL  CIN       6  ATL       3
# ...         ...  ...  ...  ...     ...  ...     ...
# 2426 2022-10-05  PHI  HOU  HOU       3  PHI       2
# 2427 2022-10-05  MIN  CWS  MIN      10  CWS       1
# 2428 2022-10-05  ATL  MIA  MIA      12  ATL       9
# 2429 2022-10-05   AZ  MIL   AZ       4  MIL       2
# 2430 2022-10-05  COL  LAD  LAD       6  COL       1
#
# [2431 rows x 7 columns]

# %% [markdown]
# ## `wins_lose_stats`
# Creates new df from regular season games df with each teams annual win rate and the year.

# %%
def win_percentage(year):
    
    year_df = clean_dates(year)

    if type(year_df) == pd.core.frame.DataFrame:
                
        # get number of wins per team and make a dict
        team_wins = dict(year_df.groupby('Win').count()["Date"])
        
        #only teams in 'agg_stats', dropping countries, ex. USA COL PRU
        for team in list(team_wins.keys()):
            if team not in MLB_5_seasons['Team'].unique():
                del team_wins[team]

        # get number of loses per team and make a dict
        team_loses = dict(year_df.groupby('Lose').count()["Date"])
        
        for team in list(team_loses.keys()):
            if team not in MLB_5_seasons['Team'].unique():
                del team_loses[team]
        

        # get annual percentage of wins
        annual_percent_wins = {k: round((v/(v+team_loses[k]))*100, 2) for (k,v) in team_wins.items()}

        per_win_without_yr = pd.DataFrame.from_dict(annual_percent_wins, orient='index', columns=[year])

        
        return per_win_without_yr

# %% [markdown]
# ### Examples

# %%
win_percentage(2020)
# Out:
# ValueError: Enter a valid year ['2022', '2021', '2019', '2018', '2017']

# %%
win_percentage(2022)
# Out:
#       2022
# ATL  62.35
# AZ   45.68
# BAL  51.23
# BOS  48.15
# CHC  45.68
# CIN  38.27
# CLE  56.79
# COL  41.98
# CWS  50.00
# DET  40.74
# HOU  65.64
# KC   40.12
# LAA  45.06
# LAD  68.52
# MIA  42.59
# MIL  53.09
# MIN  47.85
# NYM  62.35
# NYY  61.11
# OAK  37.04
# PHI  53.70
# PIT  38.27
# SD   54.94
# SEA  55.56
# SF   50.00
# STL  57.41
# TB   53.09
# TEX  41.98
# TOR  56.79
# WSH  33.95

# %% [markdown]
# # Create modeling DF

# %% [markdown]
# ## Create `agg_stats_df`
# 5 seasons of team stats. Each row is teams annual stats (gives team name and year)

# %%
mlb_teams = MLB_5_seasons['Team'].unique()
years = MLB_5_seasons['Year'].unique()

# %%
team_stats_dfs = []
for year in years:
    year_df = MLB_5_seasons[MLB_5_seasons['Year']==year]
    for team in mlb_teams:
        team_df = year_df[year_df['Team']==team]
        team_stats = extra_stats(team, year)
        team_stats_dfs.append(team_stats)

# %%
agg_stats_df = pd.concat(team_stats_dfs, ignore_index=True)   
agg_stats_df
# Out:
#     Team  Year Games Played Sum At Bats Sum Runs Sum Hits Sum Doubles Sum  \
# 0    NYM  2022             1845        6044      844     1539         295
# 1    ATL  2022             1705        5920      818     1469         311
# 2    LAD  2022             1661        5690      866     1439         324
# 3    TOR  2022             1851        6133      840     1598         344
# 4    NYY  2022             1729        5683      841     1422         239
# ..   ...   ...              ...         ...      ...      ...         ...
# 145  MIL  2017             1959        5779      777     1450         286
# 146   TB  2017             1902        5911      753     1421         260
# 147  CHC  2017             2056        5870      865     1485         285
# 148  BAL  2017             1728        5824      763     1520         270
# 149  DET  2017             1475        4701      588     1190         230
#
#     Triples Sum Home Runs Sum Runs Batted In Sum  ... Mean Runs Mean Hits  \
# 0            29           201                824  ...   35.1667    64.125
# 1            12           246                784  ...   38.9524   69.9524
# 2            31           221                832  ...   48.1111   79.9444
# 3            14           205                816  ...   49.4118        94
# 4            12           249                792  ...   44.2632   74.8421
# ..          ...           ...                ...  ...       ...       ...
# 145          24           236                741  ...   29.8846   55.7692
# 146          30           247                723  ...     30.12     56.84
# 147          30           241                835  ...    32.037        55
# 148          15           243                738  ...   33.1739    66.087
# 149          33           133                537  ...      29.4      59.5
#
#     Mean Doubles Mean Triples Mean Home Runs Mean Runs Batted In Mean Walks  \
# 0        12.2917      1.20833          8.375             34.3333    24.4167
# 1        14.8095     0.571429        11.7143             37.3333     24.619
# 2             18      1.72222        12.2778             46.2222    35.3889
# 3        20.2353     0.823529        12.0588                  48    31.7059
# 4        12.5789     0.631579        13.1053             41.6842    33.1053
# ..           ...          ...            ...                 ...        ...
# 145           11     0.923077        9.07692                28.5    22.4231
# 146         10.4          1.2           9.88               28.92      23.84
# 147      10.5556      1.11111        8.92593             30.9259    24.7407
# 148      11.7391     0.652174        10.5652              32.087    17.5652
# 149         11.5         1.65           6.65               26.85      18.75
#
#     Mean Strikeouts Mean Stolen Bases Mean Caught Stealing
# 0             57.25           2.66667              1.04167
# 1           77.5238           4.33333              1.52381
# 2           80.8333           5.55556                    1
# 3           78.1765           4.94118              2.41176
# 4           71.6842           6.05263              1.94737
# ..              ...               ...                  ...
# 145         62.1923           4.76923              1.61538
# 146           66.84               3.6                 1.48
# 147         56.6296           2.48148              1.37037
# 148         64.6522            1.6087              0.73913
# 149           52.05              2.65                  1.4
#
# [150 rows x 26 columns]

# %%
# view as a list for easy reading
list(agg_stats_df.columns)
# Out:
# ['Team',
#  'Year',
#  'Games Played Sum',
#  'At Bats Sum',
#  'Runs Sum',
#  'Hits Sum',
#  'Doubles Sum',
#  'Triples Sum',
#  'Home Runs Sum',
#  'Runs Batted In Sum',
#  'Walks Sum',
#  'Strikeouts Sum',
#  'Stolen Bases Sum',
#  'Caught Stealing Sum',
#  'Mean Games Played',
#  'Mean At Bats',
#  'Mean Runs',
#  'Mean Hits',
#  'Mean Doubles',
#  'Mean Triples',
#  'Mean Home Runs',
#  'Mean Runs Batted In',
#  'Mean Walks',
#  'Mean Strikeouts',
#  'Mean Stolen Bases',
#  'Mean Caught Stealing']

# %% [markdown]
# ## Create 5 seasons of win percentages

# %%
join_these = []
for year in years:
    join_these.append(win_percentage(year))
    
win_percent_by_year = pd.concat(join_these, axis=1)
win_percent_by_year
# Out:
#       2022   2021   2019   2018   2017
# ATL  62.35  54.32  59.88  55.56  44.44
# AZ   45.68  32.52  52.47  50.62  57.41
# BAL  51.23  32.10  33.33  29.01  46.30
# BOS  48.15  56.79  52.15  66.67  57.41
# CHC  45.68  43.83  51.85  58.54  56.79
# CIN  38.27  50.61  46.30  41.36  41.98
# CLE  56.79  49.38  57.41  56.17  62.96
# COL  41.98  45.68  43.83  55.83  53.70
# CWS  50.00  57.06  45.06  38.27  41.36
# DET  40.74  47.53  29.01  39.51  39.51
# HOU  65.64  58.64  66.05  63.58  62.35
# KC   40.12  45.68  35.98  35.80  49.38
# LAA  45.06  47.53  44.44  49.38  49.38
# LAD  68.52  65.43  65.43  56.44  64.20
# MIA  42.59  40.85  35.19  39.13  47.53
# MIL  53.09  58.64  54.94  58.90  53.09
# MIN  47.85  45.06  62.35  48.15  52.47
# NYM  62.35  48.17  52.76  47.24  43.21
# NYY  61.11  56.79  63.58  61.35  56.17
# OAK  37.04  53.09  60.12  59.88  46.30
# PHI  53.70  50.92  50.00  49.38  40.74
# PIT  38.27  37.65  42.59  50.93  46.30
# SD   54.94  49.39  43.21  40.74  43.83
# SEA  55.56  55.83  41.98  54.94  48.15
# SF   50.00  66.05  47.53  45.06  39.51
# STL  57.41  55.56  56.44  54.32  51.23
# TB   53.09  61.73  59.26  55.56  49.38
# TEX  41.98  37.04  48.15  41.36  48.15
# TOR  56.79  56.17  41.36  45.06  46.91
# WSH  33.95  40.00  57.41  50.92  59.88

# %% [markdown]
# # Add teams annual win rate to `agg_stats_df`

# %% [markdown]
# ## Add new column, fill with zeros

# %%
agg_stats_df['% wins'] = 0

agg_stats_df.tail()
# Out:
#     Team  Year Games Played Sum At Bats Sum Runs Sum Hits Sum Doubles Sum  \
# 145  MIL  2017             1959        5779      777     1450         286
# 146   TB  2017             1902        5911      753     1421         260
# 147  CHC  2017             2056        5870      865     1485         285
# 148  BAL  2017             1728        5824      763     1520         270
# 149  DET  2017             1475        4701      588     1190         230
#
#     Triples Sum Home Runs Sum Runs Batted In Sum  ... Mean Hits Mean Doubles  \
# 145          24           236                741  ...   55.7692           11
# 146          30           247                723  ...     56.84         10.4
# 147          30           241                835  ...        55      10.5556
# 148          15           243                738  ...    66.087      11.7391
# 149          33           133                537  ...      59.5         11.5
#
#     Mean Triples Mean Home Runs Mean Runs Batted In Mean Walks  \
# 145     0.923077        9.07692                28.5    22.4231
# 146          1.2           9.88               28.92      23.84
# 147      1.11111        8.92593             30.9259    24.7407
# 148     0.652174        10.5652              32.087    17.5652
# 149         1.65           6.65               26.85      18.75
#
#     Mean Strikeouts Mean Stolen Bases Mean Caught Stealing % wins
# 145         62.1923           4.76923              1.61538      0
# 146           66.84               3.6                 1.48      0
# 147         56.6296           2.48148              1.37037      0
# 148         64.6522            1.6087              0.73913      0
# 149           52.05              2.65                  1.4      0
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Fill with appropiate values

# %%
for index, row in agg_stats_df.iterrows():
    year = agg_stats_df.loc[index, 'Year']
    team = agg_stats_df.loc[index, 'Team']
    percent = win_percent_by_year.loc[team,year]

    agg_stats_df.loc[index, '% wins'] = percent
    
agg_stats_df
# Out:
#     Team  Year Games Played Sum At Bats Sum Runs Sum Hits Sum Doubles Sum  \
# 0    NYM  2022             1845        6044      844     1539         295
# 1    ATL  2022             1705        5920      818     1469         311
# 2    LAD  2022             1661        5690      866     1439         324
# 3    TOR  2022             1851        6133      840     1598         344
# 4    NYY  2022             1729        5683      841     1422         239
# ..   ...   ...              ...         ...      ...      ...         ...
# 145  MIL  2017             1959        5779      777     1450         286
# 146   TB  2017             1902        5911      753     1421         260
# 147  CHC  2017             2056        5870      865     1485         285
# 148  BAL  2017             1728        5824      763     1520         270
# 149  DET  2017             1475        4701      588     1190         230
#
#     Triples Sum Home Runs Sum Runs Batted In Sum  ... Mean Hits Mean Doubles  \
# 0            29           201                824  ...    64.125      12.2917
# 1            12           246                784  ...   69.9524      14.8095
# 2            31           221                832  ...   79.9444           18
# 3            14           205                816  ...        94      20.2353
# 4            12           249                792  ...   74.8421      12.5789
# ..          ...           ...                ...  ...       ...          ...
# 145          24           236                741  ...   55.7692           11
# 146          30           247                723  ...     56.84         10.4
# 147          30           241                835  ...        55      10.5556
# 148          15           243                738  ...    66.087      11.7391
# 149          33           133                537  ...      59.5         11.5
#
#     Mean Triples Mean Home Runs Mean Runs Batted In Mean Walks  \
# 0        1.20833          8.375             34.3333    24.4167
# 1       0.571429        11.7143             37.3333     24.619
# 2        1.72222        12.2778             46.2222    35.3889
# 3       0.823529        12.0588                  48    31.7059
# 4       0.631579        13.1053             41.6842    33.1053
# ..           ...            ...                 ...        ...
# 145     0.923077        9.07692                28.5    22.4231
# 146          1.2           9.88               28.92      23.84
# 147      1.11111        8.92593             30.9259    24.7407
# 148     0.652174        10.5652              32.087    17.5652
# 149         1.65           6.65               26.85      18.75
#
#     Mean Strikeouts Mean Stolen Bases Mean Caught Stealing % wins
# 0             57.25           2.66667              1.04167  62.35
# 1           77.5238           4.33333              1.52381  62.35
# 2           80.8333           5.55556                    1  68.52
# 3           78.1765           4.94118              2.41176  56.79
# 4           71.6842           6.05263              1.94737  61.11
# ..              ...               ...                  ...    ...
# 145         62.1923           4.76923              1.61538  53.09
# 146           66.84               3.6                 1.48  49.38
# 147         56.6296           2.48148              1.37037  56.79
# 148         64.6522            1.6087              0.73913  46.30
# 149           52.05              2.65                  1.4  39.51
#
# [150 rows x 27 columns]

# %% [markdown]
# # Save FINAL MODELING DF

# %%
pd.to_pickle(agg_stats_df, "../pickled_tables/MODELING_DF.pkl")

# %%
modeling_df = pd.read_pickle("../pickled_tables/MODELING_DF.pkl")

# %%
modeling_df
# Out:
#     Team  Year Games Played Sum At Bats Sum Runs Sum Hits Sum Doubles Sum  \
# 0    NYM  2022             1845        6044      844     1539         295
# 1    ATL  2022             1705        5920      818     1469         311
# 2    LAD  2022             1661        5690      866     1439         324
# 3    TOR  2022             1851        6133      840     1598         344
# 4    NYY  2022             1729        5683      841     1422         239
# ..   ...   ...              ...         ...      ...      ...         ...
# 145  MIL  2017             1959        5779      777     1450         286
# 146   TB  2017             1902        5911      753     1421         260
# 147  CHC  2017             2056        5870      865     1485         285
# 148  BAL  2017             1728        5824      763     1520         270
# 149  DET  2017             1475        4701      588     1190         230
#
#     Triples Sum Home Runs Sum Runs Batted In Sum  ... Mean Hits Mean Doubles  \
# 0            29           201                824  ...    64.125      12.2917
# 1            12           246                784  ...   69.9524      14.8095
# 2            31           221                832  ...   79.9444           18
# 3            14           205                816  ...        94      20.2353
# 4            12           249                792  ...   74.8421      12.5789
# ..          ...           ...                ...  ...       ...          ...
# 145          24           236                741  ...   55.7692           11
# 146          30           247                723  ...     56.84         10.4
# 147          30           241                835  ...        55      10.5556
# 148          15           243                738  ...    66.087      11.7391
# 149          33           133                537  ...      59.5         11.5
#
#     Mean Triples Mean Home Runs Mean Runs Batted In Mean Walks  \
# 0        1.20833          8.375             34.3333    24.4167
# 1       0.571429        11.7143             37.3333     24.619
# 2        1.72222        12.2778             46.2222    35.3889
# 3       0.823529        12.0588                  48    31.7059
# 4       0.631579        13.1053             41.6842    33.1053
# ..           ...            ...                 ...        ...
# 145     0.923077        9.07692                28.5    22.4231
# 146          1.2           9.88               28.92      23.84
# 147      1.11111        8.92593             30.9259    24.7407
# 148     0.652174        10.5652              32.087    17.5652
# 149         1.65           6.65               26.85      18.75
#
#     Mean Strikeouts Mean Stolen Bases Mean Caught Stealing % wins
# 0             57.25           2.66667              1.04167  62.35
# 1           77.5238           4.33333              1.52381  62.35
# 2           80.8333           5.55556                    1  68.52
# 3           78.1765           4.94118              2.41176  56.79
# 4           71.6842           6.05263              1.94737  61.11
# ..              ...               ...                  ...    ...
# 145         62.1923           4.76923              1.61538  53.09
# 146           66.84               3.6                 1.48  49.38
# 147         56.6296           2.48148              1.37037  56.79
# 148         64.6522            1.6087              0.73913  46.30
# 149           52.05              2.65                  1.4  39.51
#
# [150 rows x 27 columns]

# %%
list(modeling_df.columns)
# Out:
# ['Team',
#  'Year',
#  'Games Played Sum',
#  'At Bats Sum',
#  'Runs Sum',
#  'Hits Sum',
#  'Doubles Sum',
#  'Triples Sum',
#  'Home Runs Sum',
#  'Runs Batted In Sum',
#  'Walks Sum',
#  'Strikeouts Sum',
#  'Stolen Bases Sum',
#  'Caught Stealing Sum',
#  'Mean Games Played',
#  'Mean At Bats',
#  'Mean Runs',
#  'Mean Hits',
#  'Mean Doubles',
#  'Mean Triples',
#  'Mean Home Runs',
#  'Mean Runs Batted In',
#  'Mean Walks',
#  'Mean Strikeouts',
#  'Mean Stolen Bases',
#  'Mean Caught Stealing',
#  '% wins']

# %%
modeling_df.shape
# Out:
# (150, 27)

# %%
games_2022
# Out:
#             Day Month Date Away Home  Win W Score Lose L Score
# 0      Thursday   Apr    7  MIL  CHC  CHC       5  MIL       4
# 1      Thursday   Apr    7  CLE   KC   KC       3  CLE       1
# 2      Thursday   Apr    7  PIT  STL  STL       9  PIT       0
# 3      Thursday   Apr    7  NYM  WSH  NYM       5  WSH       1
# 4      Thursday   Apr    7  CIN  ATL  CIN       6  ATL       3
# ...         ...   ...  ...  ...  ...  ...     ...  ...     ...
# 2426  Wednesday   Oct    5  PHI  HOU  HOU       3  PHI       2
# 2427  Wednesday   Oct    5  MIN  CWS  MIN      10  CWS       1
# 2428  Wednesday   Oct    5  ATL  MIA  MIA      12  ATL       9
# 2429  Wednesday   Oct    5   AZ  MIL   AZ       4  MIL       2
# 2430  Wednesday   Oct    5  COL  LAD  LAD       6  COL       1
#
# [2431 rows x 9 columns]

# %%
MLB_5_seasons[MLB_5_seasons["Year"]=="2022"]
# Out:
#     Team  Games Played  At Bats  Runs  Hits  Doubles  Triples  Home Runs  \
# 0    NYM             2        2     1     1        0        0          1
# 1    ATL             1        4     0     3        2        0          0
# 2    LAD             4       13     6     6        2        0          1
# 3    TOR             8        9     0     6        0        0          0
# 4    NYY            47      128    28    39        9        0         15
# ..   ...           ...      ...   ...   ...      ...      ...        ...
# 789   AZ            13        0     0     0        0        0          0
# 790   AZ            29        0     0     0        0        0          0
# 791  LAA             5       11     0     0        0        0          0
# 792  NYM            30        0     0     0        0        0          0
# 793  LAD             2        4     0     0        0        0          0
#
#      Runs Batted In  Walks  Strikeouts  Stolen Bases  Caught Stealing  \
# 0                 3      0           0             0                0
# 1                 3      0           0             0                0
# 2                 3      2           7             0                0
# 3                 3      1           1             0                1
# 4                37     19          35             0                0
# ..              ...    ...         ...           ...              ...
# 789               0      0           0             0                0
# 790               0      0           0             0                0
# 791               0      0           5             0                0
# 792               0      0           0             0                0
# 793               0      0           3             0                0
#
#      Batting Average  On-Base Percentage  Slugging Percentage  \
# 0              0.500               0.500                2.000
# 1              0.750               0.750                1.250
# 2              0.462               0.563                0.846
# 3              0.667               0.700                0.667
# 4              0.305               0.412                0.727
# ..               ...                 ...                  ...
# 789            0.000               0.000                0.000
# 790            0.000               0.000                0.000
# 791            0.000               0.000                0.000
# 792            0.000               0.000                0.000
# 793            0.000               0.000                0.000
#
#      On-Base Plus Slugging  Year         Player Name Position
# 0                    2.500  2022        Khalil  Lee        CF
# 1                    2.000  2022    Chadwick  Tromp         C
# 2                    1.409  2022      James  Outman        LF
# 3                    1.367  2022        Otto  Lopez        SS
# 4                    1.139  2022    Matt  Carpenter        DH
# ..                     ...   ...                 ...      ...
# 789                  0.000  2022       Luke  Weaver         P
# 790                  0.000  2022    J.B.  Wendelken         P
# 791                  0.000  2022  Aaron  Whitefield        RF
# 792                  0.000  2022   Trevor  Williams         P
# 793                  0.000  2022      Tony  Wolters         X
#
# [794 rows x 20 columns]
